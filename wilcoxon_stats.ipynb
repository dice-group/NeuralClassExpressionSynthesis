# %%
from utils.manchester_syntax import wilcoxon_statistical_test
import warnings
warnings.filterwarnings('ignore')
import json

def search_vs_nces_stat_tests():
    print("### Semantic Bible ###\n")
    with open('datasets/semantic_bible/Results/NCES_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer+GRU+LSTM']['f1']['values']
    acc_nces = nces['SetTransformer+GRU+LSTM']['acc']['values']
    time_nces = nces['SetTransformer+GRU+LSTM']['time']['values']
    with open('datasets/semantic_bible/Results/concept_learning_results_celoe.json') as celoe_file:
        celoe = json.load(celoe_file)
    f1_celoe = celoe['F-measure']
    acc_celoe = celoe['Accuracy']
    time_celoe = celoe['Runtime']
    _, p1 = wilcoxon_statistical_test(acc_nces, acc_celoe)
    _, p2 = wilcoxon_statistical_test(f1_nces, f1_celoe)
    _, p3 = wilcoxon_statistical_test(time_nces, time_celoe)
    print("\n")
    for metric, p in zip(['Accuracy', 'F1', 'RunTime'], [p1,p2,p3]):
        print(f'On {metric} of Semantic Bible KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Mutagenesis ###\n")
    with open('datasets/mutagenesis/Results/NCES_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer+LSTM']['f1']['values']
    acc_nces = nces['SetTransformer+LSTM']['acc']['values']
    time_nces = nces['SetTransformer+LSTM']['time']['values']
    with open('datasets/mutagenesis/Results/concept_learning_results_celoe.json') as celoe_file:
        celoe = json.load(celoe_file)
    f1_celoe = celoe['F-measure']
    acc_celoe = celoe['Accuracy']
    time_celoe = celoe['Runtime']
    _, p1 = wilcoxon_statistical_test(acc_nces, acc_celoe)
    _, p2 = wilcoxon_statistical_test(f1_nces, f1_celoe)
    _, p3 = wilcoxon_statistical_test(time_nces, time_celoe)
    print("\n")
    for metric, p in zip(['Accuracy', 'F1', 'RunTime'], [p1,p2,p3]):
        print(f'On {metric} of Mutagenesis KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Carcinogenesis ###\n")    
    with open('datasets/carcinogenesis/Results/NCES_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer+GRU']['f1']['values']
    acc_nces = nces['SetTransformer+GRU']['acc']['values']
    time_nces = nces['SetTransformer+GRU']['time']['values']
    with open('datasets/carcinogenesis/Results/concept_learning_results_evolearner.json') as evo_file:
        evo = json.load(evo_file)
    acc_evo = evo['Accuracy']
    f1_evo = evo['F-measure']
    time_evo = evo['Runtime']
    _, p1 = wilcoxon_statistical_test(acc_nces, acc_evo)
    _, p2 = wilcoxon_statistical_test(f1_nces, f1_evo)
    _, p3 = wilcoxon_statistical_test(time_nces, time_evo)
    print("\n")
    for metric, p in zip(['Accuracy', 'F1', 'RunTime'], [p1, p2,p3]):
        print(f'On {metric} of Carcinogenesis KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()
        
    print("### Vicodi ###\n")    
    with open('datasets/vicodi/Results/NCES_Ensemble.json') as file:
        nces = json.load(file)
    f1_nces = nces['SetTransformer+LSTM']['f1']['values']
    acc_nces = nces['SetTransformer+LSTM']['acc']['values']
    time_nces = nces['SetTransformer+LSTM']['time']['values']
    with open('datasets/vicodi/Results/concept_learning_results_ecii.json') as ecii_file:
        ecii = json.load(ecii_file)
    f1_ecii = ecii['F-measure']
    time_ecii = ecii['Runtime']
    _, p2 = wilcoxon_statistical_test(f1_nces, f1_ecii)
    _, p3 = wilcoxon_statistical_test(time_nces, time_ecii)
    for metric, p in zip(['F1', 'RunTime'], [p2,p3]):
        print(f'On {metric} of Vicodi KG, p_value = ', p)
        if p<=0.05:
            print('* Probably different distributions *')
        else:
            print('Probably the same distribution')
        print()

# %%
search_vs_nces_stat_tests()
# Out:
# ### Semantic Bible ###
#
# stat=89.000, p=0.136
# stat=58.000, p=0.015
# stat=0.000, p=0.000
#
#
# On Accuracy of Semantic Bible KG, p_value =  0.13613677630087
# Probably the same distribution
#
# On F1 of Semantic Bible KG, p_value =  0.0149661863394141
# * Probably different distributions *
#
# On RunTime of Semantic Bible KG, p_value =  8.291147751986402e-06
# * Probably different distributions *
#
# ### Mutagenesis ###
#
# stat=25.000, p=0.150
# stat=19.000, p=0.064
# stat=1.000, p=0.000
#
#
# On Accuracy of Mutagenesis KG, p_value =  0.15020211409413223
# Probably the same distribution
#
# On F1 of Mutagenesis KG, p_value =  0.06403014843302322
# Probably the same distribution
#
# On RunTime of Mutagenesis KG, p_value =  9.5367431640625e-07
# * Probably different distributions *
#
# ### Carcinogenesis ###
#
# stat=612.000, p=0.000
# stat=538.500, p=0.000
# stat=0.000, p=0.000
#
#
# On Accuracy of Carcinogenesis KG, p_value =  1.6603259286368137e-07
# * Probably different distributions *
#
# On F1 of Carcinogenesis KG, p_value =  2.7107509978952958e-08
# * Probably different distributions *
#
# On RunTime of Carcinogenesis KG, p_value =  8.33039747348591e-18
# * Probably different distributions *
#
# ### Vicodi ###
#
# stat=0.000, p=0.000
# stat=0.000, p=0.000
# On F1 of Vicodi KG, p_value =  2.1526488074099054e-27
# * Probably different distributions *
#
# On RunTime of Vicodi KG, p_value =  1.628958993624077e-27
# * Probably different distributions *
